# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load the decentralized evolution file
base_dir = os.path.dirname(os.path.abspath('compare_fitness.ipynb'))
decentralized_path = os.path.join(base_dir, 'Individual Legs Parallel', 'controllers', 'leg_5_disabled_indiv_legs', 'data', 'evolution_data.csv')
decentralized_data = pd.read_csv(decentralized_path)

# Filter data to include only generations up to 3000
decentralized_data = decentralized_data[decentralized_data['Generation'] <= 3000]

# Get unique leg indices
leg_indices = decentralized_data['Leg Index'].unique()

# Create a plot for each leg on the same graph
plt.figure(figsize=(30, 10))

leg_index = 0
# Filter data for leg 0
leg_data = decentralized_data[decentralized_data['Leg Index'] == leg_index]

# Group by generation and calculate the mean fitness for each generation
fitness_over_time = leg_data.groupby('Generation')['Fitness'].mean()

# Plot the fitness over time for the current leg
plt.plot(fitness_over_time, label='Decentralized Mean Fitness', color='#FFA800')

# Load the centralized evolution file
centralized_path = os.path.join(base_dir, 'Original', 'controllers', 'leg_5_disabled_original_ga', 'data', 'evolution_data.csv')
centralized_evolution = pd.read_csv(centralized_path)

# Filter data to include only generations up to 3000
centralized_data = centralized_evolution[centralized_evolution['Generation'] <= 3000]

# Calculate mean fitness for each generation
mean_fitness = centralized_data.groupby('Generation')['Fitness'].mean()

# Plot the data
plt.plot(mean_fitness.index, mean_fitness.values, linestyle='-', color='b', label='Centralized Mean Fitness')

# Add title and labels
plt.title('Mean Fitness Over Time for Each Leg - Decentralized vs Centralized Evolution - Leg 5 Disabled')
plt.xlabel('Generation')
plt.ylabel('Mean Fitness')
plt.grid(True)

# Set y/x-axis limits
plt.ylim(0, 90)
plt.xlim(0, 3000)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')

# Adjust layout to make room for the legend
plt.tight_layout(rect=[0, 0, 0.85, 1])

# Show plot
plt.show()

# %%
# Load the decentralized evolution file
base_dir = os.path.dirname(os.path.abspath('compare_fitness.ipynb'))
decentralized_path = os.path.join(base_dir, 'Individual Legs Parallel', 'controllers', 'leg_5_disabled_indiv_legs', 'data', 'evolution_data.csv')
decentralized_data = pd.read_csv(decentralized_path)

# Filter data to include only generations up to 3000
decentralized_data = decentralized_data[decentralized_data['Generation'] <= 3000]

# Get unique leg indices
leg_indices = decentralized_data['Leg Index'].unique()

# Create a plot for each leg on the same graph
plt.figure(figsize=(30, 10))

leg_index = 0
# Filter data for leg 0
leg_data = decentralized_data[decentralized_data['Leg Index'] == leg_index]

# Group by generation and calculate the max fitness for each generation
fitness_over_time = leg_data.groupby('Generation')['Fitness'].max()

# Plot the fitness over time for the current leg
plt.plot(fitness_over_time, label='Decentralized Max Fitness', color='#FFA800')

# Load the centralized evolution file
centralized_path = os.path.join(base_dir, 'Original', 'controllers', 'leg_5_disabled_original_ga', 'data', 'evolution_data.csv')
centralized_evolution = pd.read_csv(centralized_path)

# Filter data to include only generations up to 3000
centralized_data = centralized_evolution[centralized_evolution['Generation'] <= 3000]

# Calculate max fitness for each generation
max_fitness = centralized_data.groupby('Generation')['Fitness'].max()

# Plot the data
plt.plot(max_fitness.index, max_fitness.values, linestyle='-', color='b', label='Centralized Max Fitness')

# Add title and labels
plt.title('Maximum Fitness Over Time for Each Leg - Decentralized vs Centralized Evolution - Leg 5 Disabled')
plt.xlabel('Generation')
plt.ylabel('Maximum Fitness')
plt.grid(True)

# Set y/x-axis limits
plt.ylim(0, 90)
plt.xlim(0, 3000)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')

# Adjust layout to make room for the legend
plt.tight_layout(rect=[0, 0, 0.85, 1])

# Show plot
plt.show()

# %%
# Load the decentralized evolution file
base_dir = os.path.dirname(os.path.abspath('compare_fitness.ipynb'))
decentralized_path = os.path.join(base_dir, 'Individual Legs Parallel', 'controllers', 'leg_5_disabled_indiv_legs', 'data', 'evolution_data.csv')
decentralized_data = pd.read_csv(decentralized_path)

# Filter data to include only generations up to 3000
decentralized_data = decentralized_data[decentralized_data['Generation'] <= 3000]

# Get unique leg indices
leg_indices = decentralized_data['Leg Index'].unique()

# Create a plot for each leg on the same graph
plt.figure(figsize=(30, 10))

leg_index = 0
# Filter data for leg 0
leg_data = decentralized_data[decentralized_data['Leg Index'] == leg_index]

# Group by generation and calculate the mean fitness for each generation
fitness_over_time = leg_data.groupby('Generation')['Fitness'].mean()

# Plot the fitness over time for the current leg
plt.plot(fitness_over_time, label='Decentralized Mean Fitness', color='#FFA800')

# Load the centralized evolution file
centralized_path = os.path.join(base_dir, 'Original', 'controllers', 'leg_5_disabled_original_ga', 'data', 'evolution_data.csv')
centralized_evolution = pd.read_csv(centralized_path)

# Filter data to include only generations up to 3000
centralized_data = centralized_evolution[centralized_evolution['Generation'] <= 3000]

# Calculate mean fitness for each generation
mean_fitness = centralized_data.groupby('Generation')['Fitness'].mean()

# Plot the data
plt.plot(mean_fitness.index, mean_fitness.values, linestyle='-', color='b', label='Centralized Mean Fitness')

# Load the cooperative coevolution file
coop_path = os.path.join(base_dir, 'Individual Legs', 'controllers', 'leg_5_disabled_indiv_legs', 'data', 'evolution_data.csv')
coop_data = pd.read_csv(coop_path)

# Get unique leg indices
leg_indices = coop_data['Leg Index'].unique()

# Filter data to include only generations up to 3000
coop_data = coop_data[coop_data['Effective Generation'] <= 3000]

# Get unique leg indices
leg_indices = coop_data['Leg Index'].unique()
# Filter data to include only generations up to 3000

color_map = {
    0: '#648FFF',  # Blue
    1: '#785EF0',  # Purple
    2: '#DC267F',  # Pink
    3: '#FE6100',  # Orange
    4: '#FFB000',  # Yellow
    5: '#D8E286',  # Lime
}

for leg_index in leg_indices:
    # Filter data for the current leg
    leg_data = coop_data[coop_data['Leg Index'] == leg_index]
    
    # Group by generation and calculate the mean fitness for each generation
    fitness_over_time = leg_data.groupby('Effective Generation')['Fitness'].mean()
    
    # Plot the fitness over time for the current leg
    color = color_map.get(leg_index, 'k')  # Default to black if leg index not in color_map
    plt.plot(fitness_over_time, label=f'Cooperative Coevolution Max Fitness Leg {leg_index}', 
            color=color, marker='o', markersize=2, linestyle='-', linewidth=0.5)
# Add title and labels
plt.title('Mean Fitness Over Time - Decentralized vs Centralized vs Cooperative Coevolution - Leg 5 Disabled')
plt.xlabel('Effective Generation')
plt.ylabel('Mean Fitness')
plt.grid(True)

# Set y/x-axis limits
plt.ylim(0, 90)
plt.xlim(0, 3000)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')

# Adjust layout to make room for the legend
plt.tight_layout(rect=[0, 0, 0.85, 1])

# Show plot
plt.show()

# %%
# Load the decentralized evolution file
base_dir = os.path.dirname(os.path.abspath('compare_fitness.ipynb'))
decentralized_path = os.path.join(base_dir, 'Individual Legs Parallel', 'controllers', 'leg_5_disabled_indiv_legs', 'data', 'evolution_data.csv')
decentralized_data = pd.read_csv(decentralized_path)

# Filter data to include only generations up to 3000
decentralized_data = decentralized_data[decentralized_data['Generation'] <= 3000]

# Get unique leg indices
leg_indices = decentralized_data['Leg Index'].unique()

# Create a plot for each leg on the same graph
plt.figure(figsize=(30, 10))

leg_index = 0
# Filter data for leg 0
leg_data = decentralized_data[decentralized_data['Leg Index'] == leg_index]

# Group by generation and calculate the max fitness for each generation
fitness_over_time = leg_data.groupby('Generation')['Fitness'].max()

# Plot the fitness over time for the current leg
plt.plot(fitness_over_time, label='Decentralized Max Fitness', color='#FFA800')

# Load the centralized evolution file
centralized_path = os.path.join(base_dir, 'Original', 'controllers', 'leg_5_disabled_original_ga', 'data', 'evolution_data.csv')
centralized_evolution = pd.read_csv(centralized_path)

# Filter data to include only generations up to 3000
centralized_data = centralized_evolution[centralized_evolution['Generation'] <= 3000]

# Calculate max fitness for each generation
max_fitness = centralized_data.groupby('Generation')['Fitness'].max()

# Plot the data
plt.plot(max_fitness.index, max_fitness.values, linestyle='-', color='b', label='Centralized Max Fitness')

# Load the cooperative coevolution file
coop_path = os.path.join(base_dir, 'Individual Legs', 'controllers', 'leg_5_disabled_indiv_legs', 'data', 'evolution_data.csv')
coop_data = pd.read_csv(coop_path)

# Get unique leg indices
leg_indices = coop_data['Leg Index'].unique()

# Filter data to include only generations up to 3000
coop_data = coop_data[coop_data['Effective Generation'] <= 3000]

# Get unique leg indices
leg_indices = coop_data['Leg Index'].unique()
# Filter data to include only generations up to 3000

color_map = {
    0: '#648FFF',  # Blue
    1: '#785EF0',  # Purple
    2: '#DC267F',  # Pink
    3: '#FE6100',  # Orange
    4: '#FFB000',  # Yellow
    5: '#D8E286',  # Lime
}

for leg_index in leg_indices:
    # Filter data for the current leg
    leg_data = coop_data[coop_data['Leg Index'] == leg_index]
    
    # Group by generation and calculate the mean fitness for each generation
    fitness_over_time = leg_data.groupby('Effective Generation')['Fitness'].mean()
    
    # Plot the fitness over time for the current leg
    color = color_map.get(leg_index, 'k')  # Default to black if leg index not in color_map
    plt.plot(fitness_over_time, label=f'Cooperative Coevolution Max Fitness Leg {leg_index}', 
            color=color, marker='o', markersize=2, linestyle='-', linewidth=0.5)
    
# Add title and labels
plt.title('Max Fitness Over Time - Decentralized vs Centralized vs Cooperative Coevolution - Leg 5 Disabled')
plt.xlabel('Effective Generation')
plt.ylabel('Max Fitness')
plt.grid(True)

# Set y/x-axis limits
plt.ylim(0, 90)
plt.xlim(0, 3000)

# Add legend outside the plot
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')

# Adjust layout to make room for the legend
plt.tight_layout(rect=[0, 0, 0.85, 1])

# Show plot
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
