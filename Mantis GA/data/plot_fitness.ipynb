# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
file_path = 'evolution_data.csv'
data = pd.read_csv(file_path)

# Extract relevant columns
generations = data['Generation']
fitness = data['Fitness']

# Plot the data
plt.figure(figsize=(30, 10))
plt.plot(generations, fitness, marker='o', linestyle='-', color='b', label='Fitness')

# Add labels and title
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Fitness Over Generations')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot each leg's fitness over time individually with consistent colors
for i, leg_index in enumerate(leg_indices):
    # Filter data for the current leg
    leg_data = data[data['Leg Index'] == leg_index]
    
    # Group by generation and calculate the mean fitness for each generation
    fitness_over_time = leg_data.groupby('Generation')['Fitness'].mean()
    
    # Create a new figure for each leg
    plt.figure(figsize=(30, 10))
    
    # Plot the fitness over time for the current leg
    plt.plot(fitness_over_time, marker='o', label=f'Leg {leg_index}', color=colors[i])
    
    # Add title and labels
    plt.title(f'Fitness Over Time for Leg {leg_index}')
    plt.xlabel('Generation')
    plt.ylabel('Mean Fitness')
    plt.grid(True)
    
    # Add legend
    plt.legend()
    
    # Show plot
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Plot each leg's fitness over time individually with consistent colors
# ----> 2 for i, leg_index in enumerate(leg_indices):
#       3     # Filter data for the current leg
#       4     leg_data = data[data['Leg Index'] == leg_index]
#       6     # Group by generation and calculate the mean fitness for each generation
#
# NameError: name 'leg_indices' is not defined
